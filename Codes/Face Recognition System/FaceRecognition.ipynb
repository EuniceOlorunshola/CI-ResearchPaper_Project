# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow 
from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
from mtcnn.mtcnn import MTCNN

# %%
classifier_model = cv2.CascadeClassifier(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\haarcascade_frontalface_default.xml')

# %%
#read image using imread() function
faceimage = cv2.imread(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\images.jpg')
classifier_model = cv2.CascadeClassifier(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\haarcascade_frontalface_default.xml')
boundingbox = classifier_model.detectMultiScale(faceimage)
# print bounding box for each detected face
for box in boundingbox:
    print(box)
# Out:
# [204  46  32  32]
# [54 52 30 30]

# %%
#read image using imread() function
faceimage = cv2.imread(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\images.jpg')
classifier_model = cv2.CascadeClassifier(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\haarcascade_frontalface_default.xml')
boundingbox = classifier_model.detectMultiScale(faceimage)
for box in boundingbox:
    x, y, width, height = box
    x2, y2, = x + width, y + height
    cv2.rectangle(faceimage, (x, y), (x2, y2), (0, 255, 0), 2)
    # print the character face on the image faces
    cv2.putText(faceimage, "Face", (x-10, y-10), cv2.FONT_HERSHEY_TRIPLEX, 0.5, (0,255, 0),2)
    plt.imshow(faceimage)

# %%
#load input image from file
face_inputimage = (r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\images.jpg')
faceimage = plt.imread(face_inputimage)
#create the detector, using default weights
detector_method = MTCNN()
#detect faces in the image 
faces_trained = detector.detect_faces(faceimage)
for face in faces_trained:
    print(face)
def generate_inputimage_with_bounding_box(face_inputimage, result_data_list):
        input_data = pyplot.imread(face_inputimage)
        pyplot.imshow(input_data)
        ax = pyplot.gca()
        for plot_result in result_data_list:z
        x, y, width, height = plot_result['box']
        bounding_shape = Rectangle((x,y), width, height, fill=False, color='red')
        ax.add_patch(bounding_shape)
        #show the results as a list
        pyplot.show()
# Out:
# {'box': [204, 44, 25, 33], 'confidence': 0.999953031539917, 'keypoints': {'left_eye': (214, 57), 'right_eye': (226, 58), 'nose': (222, 65), 'mouth_left': (215, 72), 'mouth_right': (223, 72)}}
# {'box': [60, 50, 25, 33], 'confidence': 0.9997227787971497, 'keypoints': {'left_eye': (63, 63), 'right_eye': (74, 62), 'nose': (65, 69), 'mouth_left': (64, 76), 'mouth_right': (74, 76)}}

# %%
#draw an image with detected objects
def generate_inputimage_with_bounding_box(face_inputimage, result_data_list):
    input_data = plt.imread(face_inputimage)
    plt.imshow(input_data)
    ax=plt.gca()
    for plot_result in result_data_list:
        x, y, width, height = plot_result['box']
        bounding_shape = Rectangle((x,y), width , height, fill=False, color = 'lightgreen')
        ax.add_patch(bounding_shape)
    plt.show()
face_inputimage = (r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\images.jpg')
faceimage = plt.imread(face_inputimage)
#use multiconvunltion neural network method
detector_method = MTCNN()
faces_trained = detector.detect_faces(faceimage)
generate_inputimage_with_bounding_box(face_inputimage, faces_trained)

# %%
def generate_inputimage_with_bounding_box(face_inputimage, result_data_list):
    input_data = plt.imread(face_inputimage)
    plt.imshow(input_data)
    ax = plt.gca()
    for plot_result in result_data_list:
        x, y, width, height = plot_result['box']
        bounding_shot = Rectangle((x,y), width, height, fill = False, color='red')
        ax.add_patch(bounding_shot)
        for key, value in plot_result['keypoints'].items():
            dot_face = Circle(value, radius=2, color='red')
            ax.add_patch(dot_face)
    plt.show()
face_inputimage =(r'C:\Users\terry\Documents\ResearchPaper\FaceDetection\images.jpg')
faceimage = plt.imread(face_inputimage)
detector_method = MTCNN()
faces_trained = detector.detect_faces(faceimage)
generate_inputimage_with_bounding_box(face_inputimage, faces_trained)
